# %% [markdown]
# # 02 — Naive baselines (E01, E02)
#
# Requires `data/processed/hourly_panel.parquet`.

# %%
import sys
from pathlib import Path

ROOT = Path("..").resolve()
if not (ROOT / "VERSION").exists():
    ROOT = Path("/kaggle/working/household-energy-forecasting")
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.config import load_data_config, load_experiment
from src.data.pipeline import load_processed_panel
from src.eval.baselines import evaluate_naive

data_cfg = load_data_config()
panel, split = load_processed_panel(data_cfg)
for cfg_path in [
    "configs/experiment/e01_seasonal_naive.yaml",
    "configs/experiment/e02_persistence.yaml",
]:
    exp = load_experiment(cfg_path)
    metrics = evaluate_naive(panel, split, exp, data_cfg)
    print(exp["id"], metrics)
